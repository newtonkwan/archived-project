# %% [markdown]
# ### Game states for a 3x2 version of the Royal Game of Ur

# %% [markdown]
# $$
# \begin{bmatrix}
#     W1 & W2 \\
#     N1 & N2\\
#     B1 & B2 \\
# \end{bmatrix}
# $$

# %% [markdown]
# With just one black piece and one white piece, we can write out all of the possible game states and extrapolate from there. Say you can only roll 0's and 1's. Arbitrarily choose that white goes first

# %% [markdown]
# $$
# 1.
# \begin{bmatrix}
#     W & 0 \\
#     0 & 0 \\
#     B & 0 \\
# \end{bmatrix}
# 2.
# \begin{bmatrix}
#     0 & 0 \\
#     W & 0 \\
#     B & 0 \\
# \end{bmatrix}
# 3.
# \begin{bmatrix}
#     0 & 0 \\
#     0 & W \\
#     B & 0 \\
# \end{bmatrix}
# 4.
# \begin{bmatrix}
#     0 & W \\
#     0 & 0 \\
#     B & 0 \\
# \end{bmatrix}
# 5.
# \begin{bmatrix}
#     W & 0 \\
#     B & 0 \\
#     0 & 0 \\
# \end{bmatrix}
# 6.
# \begin{bmatrix}
#     0 & 0 \\
#     B & W \\
#     0 & 0 \\
# \end{bmatrix}
# 7.
# \begin{bmatrix}
#     0 & W \\
#     B & 0 \\
#     0 & 0 \\
# \end{bmatrix}
# 8.
# \begin{bmatrix}
#     W & 0 \\
#     0 & B \\
#     0 & 0 \\
# \end{bmatrix}
# 9.
# \begin{bmatrix}
#     0 & 0 \\
#     W & B \\
#     0 & 0 \\
# \end{bmatrix}
# 10.
# \begin{bmatrix}
#     0 & W \\
#     0 & B \\
#     0 & 0 \\
# \end{bmatrix}
# 11.
# \begin{bmatrix}
#     W & 0 \\
#     0 & 0 \\
#     0 & B \\
# \end{bmatrix}
# 12.
# \begin{bmatrix}
#     0 & 0 \\
#     W & 0 \\
#     0 & B \\
# \end{bmatrix}
# 13.
# \begin{bmatrix}
#     0 & 0 \\
#     0 & W \\
#     0 & B \\
# \end{bmatrix}
# 14.
# \begin{bmatrix}
#     0 & W \\
#     0 & 0 \\
#     0 & B \\
# \end{bmatrix}
# $$

# %% [markdown]
# There are 14 possible configurations of the board, each of which is possible if the possible rolls are 0 and 1. It is crucial that we consider the possibility of a 0 because we would not be able to get certain board configurations if each player always needed to advance.

# %% [markdown]
# The win states above are as follows:

# %% [markdown]
# $$
# 1.
# \begin{bmatrix}
#     0 & W \\
#     0 & 0 \\
#     B & 0 \\
# \end{bmatrix}
# 2.
# \begin{bmatrix}
#     0 & W \\
#     B & 0 \\
#     0 & 0 \\
# \end{bmatrix}
# 3.
# \begin{bmatrix}
#     0 & W \\
#     0 & B \\
#     0 & 0 \\
# \end{bmatrix}
# 4.
# \begin{bmatrix}
#     W & 0 \\
#     0 & 0 \\
#     0 & B \\
# \end{bmatrix}
# 5.
# \begin{bmatrix}
#     0 & 0 \\
#     W & 0 \\
#     0 & B \\
# \end{bmatrix}
# 6.
# \begin{bmatrix}
#     0 & 0 \\
#     0 & W \\
#     0 & B \\
# \end{bmatrix}
# 7.
# \begin{bmatrix}
#     0 & W \\
#     0 & 0 \\
#     0 & B \\
# \end{bmatrix}
# $$

# %% [markdown]
# The 7th winstate is clearly not possible because the game terminates when one player reaches the end zone, so we delete it from our list of possible win states

# %% [markdown]
# $$
# 1.
# \begin{bmatrix}
#     0 & W \\
#     0 & 0 \\
#     B & 0 \\
# \end{bmatrix}
# 2.
# \begin{bmatrix}
#     0 & W \\
#     B & 0 \\
#     0 & 0 \\
# \end{bmatrix}
# 3.
# \begin{bmatrix}
#     0 & W \\
#     0 & B \\
#     0 & 0 \\
# \end{bmatrix}
# 4.
# \begin{bmatrix}
#     W & 0 \\
#     0 & 0 \\
#     0 & B \\
# \end{bmatrix}
# 5.
# \begin{bmatrix}
#     0 & 0 \\
#     W & 0 \\
#     0 & B \\
# \end{bmatrix}
# 6.
# \begin{bmatrix}
#     0 & 0 \\
#     0 & W \\
#     0 & B \\
# \end{bmatrix}
# $$

# %% [markdown]
# Let us now consider the possible ways to get to each win state. For example, we will take the possibility of ending on win game state 2 from the initial game state

# %% [markdown]
# $$
# 1.
# \begin{bmatrix}
#     W & 0 \\
#     0 & 0 \\
#     B & 0 \\
# \end{bmatrix}
# \text{White's turn (rolls 1)}
# $$
# $$
# 2.
# \begin{bmatrix}
#     0 & 0 \\
#     W & 0 \\
#     B & 0 \\
# \end{bmatrix}
# \text{Black's turn (rolls 0)}
# $$
# $$
# 3.
# \begin{bmatrix}
#     0 & 0 \\
#     W & 0 \\
#     B & 0 \\
# \end{bmatrix}
# \text{White's turn (rolls 1)}
# $$
# $$
# 4.
# \begin{bmatrix}
#     0 & 0 \\
#     0 & W \\
#     B & 0 \\
# \end{bmatrix}
# \text{Black's turn (rolls 0)}
# $$
# $$
# 5.
# \begin{bmatrix}
#     0 & 0 \\
#     0 & W \\
#     B & 0 \\
# \end{bmatrix}
# \text{White's turn (rolls 1)}
# $$
# $$
# 6.
# \begin{bmatrix}
#     0 & W \\
#     0 & 0 \\
#     B & 0 \\
# \end{bmatrix}
# \text{end win state 2}
# $$
